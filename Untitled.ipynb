# %%
pip install ultralytics
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
#pip install cvzone

# %%
from ultralytics import YOLO
import cv2
import matplotlib.pyplot as plt
import cvzone

# %%
model=YOLO('yolov8n.pt')

# %%
model=YOLO('../Yolo-Weights/yolov8l.pt')#getting better results

# %% [markdown]
# # YOLO With Given Image

# %%
result=model("RS7840_ThinkstockPhotos-515262698-hig.jpg",show=True)
cv2.waitKey(0)
# Out:
# image 1/1 C:\Users\adars\Data Science\Projects\Object Detection\RS7840_ThinkstockPhotos-515262698-hig.jpg: 448x640 3 persons, 1 bus, 2 backpacks, 2 handbags, 945.5ms
# Speed: 10.3ms preprocess, 945.5ms inference, 3.9ms postprocess per image at shape (1, 3, 448, 640)
# -1

# %%
result=model("3867702.jpg",show=True)
cv2.waitKey(0)
# Out:
# image 1/1 C:\Users\adars\Data Science\Projects\Object Detection\3867702.jpg: 384x640 9 cars, 3 motorcycles, 884.4ms
# Speed: 4.0ms preprocess, 884.4ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
# -1

# %%
import cv2
cap = cv2.VideoCapture(0)
cap.set(3, 1240)
cap.set(4, 480)
while True:
    ret, img= cap.read()
    cv2.imshow('Webcam', img)
    cv2.waitKey(1)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[8], line 7
#       5 while True:
#       6     ret, img= cap.read()
# ----> 7     cv2.imshow('Webcam', img)
#       8     cv2.waitKey(1)
#
# File ~\anaconda3\Lib\site-packages\ultralytics\utils\patches.py:56, in imshow(winname, mat)
#      48 def imshow(winname: str, mat: np.ndarray):
#      49     """
#      50     Displays an image in the specified window.
#      51
#    (...)
#      54         mat (np.ndarray): Image to be shown.
#      55     """
# ---> 56     _imshow(winname.encode("unicode_escape").decode(), mat)
#
# error: OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\highgui\src\window.cpp:971: error: (-215:Assertion failed) size.width>0 && size.height>0 in function 'cv::imshow'

# %% [markdown]
# # YOLO with Webcam

# %%
from ultralytics import YOLO
import cv2
import matplotlib.pyplot as plt
import cvzone

cap=cv2.VideoCapture(1)
cap.set(3,1280)
cap.set(4,780)
if not cap.isOpened():
    cap=cv2.VideoCapture(0)
if not cap.isOpened():
    raise IOError("Cannot open Webcam")


model=YOLO('../Yolo-Weights/yolov8n.pt')
classNames = ["person", "bicycle", "car", "motorbike", "aeroplane", "bus", "train", "truck", "boat",
              "traffic light", "fire hydrant", "stop sign", "parking meter", "bench", "bird", "cat",
              "dog", "horse", "sheep", "cow", "elephant", "bear", "zebra", "giraffe", "backpack", "umbrella",
              "handbag", "tie", "suitcase", "frisbee", "skis", "snowboard", "sports ball", "kite", "baseball bat",
              "baseball glove", "skateboard", "surfboard", "tennis racket", "bottle", "wine glass", "cup",
              "fork", "knife", "spoon", "bowl", "banana", "apple", "sandwich", "orange", "broccoli",
              "carrot", "hot dog", "pizza", "donut", "cake", "chair", "sofa", "pottedplant", "bed",
              "diningtable", "toilet", "tvmonitor", "laptop", "mouse", "remote", "keyboard", "cell phone",
              "microwave", "oven", "toaster", "sink", "refrigerator", "book", "clock", "vase", "scissors",
              "teddy bear", "hair drier", "toothbrush"
              ] 
while True:
    ret,frame=cap.read()
    results=model(frame,stream=True)
    font=cv2.FONT_HERSHEY_SIMPLEX
    #check bounding boxes
    for i in results:
        boxes=i.boxes
        for box in boxes:
            x1,y1,x2,y2=box.xyxy[0]
            x1,y1,x2,y2=int(x1),int(y1),int(x2),int(y2)
            print(x1,y1,x2,y2)
            cv2.rectangle(frame,(x1,y1),(x2,y2),(0,200,0),3)
            cls=int(box.cls[0])
            
            #cv2.putText(frame,classname[cls],(0,200),font,2,(255,0,0),3,cv2.LINE_4);
            cvzone.putTextRect(frame,f'{classNames[cls]}',(max(0,x1),max(35,y1)),scale=2.0)
    cv2.imshow("Image",frame)
    cv2.waitKey(1)
# Out:
# 0: 480x640 1 person, 284.1ms
# 85 99 582 479
# Speed: 11.7ms preprocess, 284.1ms inference, 11.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 142.7ms
# 79 96 580 479
# Speed: 2.1ms preprocess, 142.7ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 140.7ms
# 80 95 578 479
# Speed: 2.9ms preprocess, 140.7ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 135.1ms
# 82 95 580 479
# Speed: 2.1ms preprocess, 135.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 143.7ms
# 82 95 579 479
# Speed: 1.3ms preprocess, 143.7ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 130.7ms
# 82 98 578 479
# Speed: 3.1ms preprocess, 130.7ms inference, 7.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 144.7ms
# 83 95 578 479
# ...

# %%
cv2.destroyAllWindows()

# %% [markdown]
# # People Counter
